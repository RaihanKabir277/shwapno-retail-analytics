# %%
# %sql
create catalog if not exists Data_Analysis_Retail;

# %%
# %sql
use catalog Data_Analysis_Retail;

# %%
# %sql
create schema if not exists Data_Analysis_Retail.gold;

# %%
# %sql
show databases from Data_Analysis_Retail;

# %%
# %sql
create schema if not exists Data_Analysis_Retail.source_data;
